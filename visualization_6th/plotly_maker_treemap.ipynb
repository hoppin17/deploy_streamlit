# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('5.5_real_final.xlsx')

# %%
df
# Out:
#      Unnamed: 0.1  Unnamed: 0   순위            영화명         개봉일  \
# 0               0           0    1             명량   2014.7.30
# 1               1           1    2           극한직업   2019.1.23
# 2               2           2    3      신과함께-죄와 벌  2017.12.20
# 3               3           3    4           국제시장  2014.12.17
# 4               4           4    5            베테랑    2015.8.5
# ..            ...         ...  ...            ...         ...
# 494           494         494  496         마음이...  2006.10.26
# 495           495         495  497  점박이:한반도의 공룡3D   2012.1.26
# 496           496         496  498            서편제   1993.4.10
# 497           497         497  499        파괴된 사나이    2010.7.1
# 498           498         498  500         오직 그대만  2011.10.20
#
#                  매출액         관객수   스크린수            배급사 coach  \
# 0    135,748,398,910  17,613,682  1,587         씨제이이엔엠   김한민
# 1    139,647,979,516  16,264,944  1,978         씨제이이엔엠   이병헌
# ...

# %%
df['배급사'] = df['배급사'].fillna('없음')

# %%
df['배급사'].isnull().sum()
# Out:
# 0

# %%
df['배급사'].unique()
# Out:
# array(['씨제이이엔엠', '롯데쇼핑㈜롯데엔터테인먼트', '플러스엠 엔터테인먼트', '쇼박스',
#        '넥스트엔터테인먼트월드(NEW)', '주식회사 에이비오엔터테인먼트,플러스엠 엔터테인먼트', '시네마서비스',
#        '롯데컬처웍스롯데엔터테인먼트', '다자인소프트,쇼박스', '씨제이이엔엠,덱스터스튜디오', '워너브러더스 코리아',
#        '이십세기폭스코리아', '플러스엠 엔터테인먼트,키위미디어그룹', '없음', 'CGV아트하우스,대명문화공장',
#        '롯데컬처웍스롯데엔터테인먼트,에이스메이커무비웍스', '씨제이이엔엠,시네마서비스', '싸이더스',
#        '롯데쇼핑㈜롯데엔터테인먼트,싸이더스', '와우픽쳐스', '에이스메이커무비웍스,키위미디어그룹',
#        '롯데쇼핑㈜롯데엔터테인먼트,리틀빅픽쳐스', '쇼이스트,씨제이이엔엠', '코리아픽쳐스', '영화사청어람',
#        '프라임엔터테인먼트', '아이러브시네마', '인벤트스톤,영화사청어람', '㈜인디스토리', '씨네월드',
#        '에이스메이커무비웍스', '필라멘트픽쳐스', '엠케이픽처스', '오퍼스픽쳐스(유),CGV아트하우스',
#        '엠케이픽처스 ,두엔터테인먼트', '씨제이이엔엠,아이러브시네마', '쇼이스트', '쇼박스,이십세기폭스코리아',
#        '마인드마크', '에스케이플래닛,씨제이이엔엠', '씨네그루다우기술', '홈초이스,싸이더스', '튜브엔터테인먼트',
#        '시너지하우스 (시너지)', '메리크리스마스,TCO더콘텐츠온', '넥스트엔터테인먼트월드(NEW),에스비에스콘텐츠허브',
#        'CGV아트하우스,영화사 풀', '이언픽쳐스,시네마서비스', '씨너스엔터테인먼트,타임스토리그룹', '에스케이텔레콤',
#        'CGV아트하우스', '㈜스튜디오이쩜영', '팝엔터테인먼트,씨제이이엔엠', '(유)씨에이치엔터테인먼트',
# ...

# %%
df['관객수'] = df['관객수'].str.replace(',', '').astype(int)

# %% [markdown]
# 위와 같은 트리맵으로 장르별로 한번 쪼개보자!

# %%
df
# Out:
#      Unnamed: 0.1  Unnamed: 0   순위            영화명         개봉일  \
# 0               0           0    1             명량   2014.7.30
# 1               1           1    2           극한직업   2019.1.23
# 2               2           2    3      신과함께-죄와 벌  2017.12.20
# 3               3           3    4           국제시장  2014.12.17
# 4               4           4    5            베테랑    2015.8.5
# ..            ...         ...  ...            ...         ...
# 494           494         494  496         마음이...  2006.10.26
# 495           495         495  497  점박이:한반도의 공룡3D   2012.1.26
# 496           496         496  498            서편제   1993.4.10
# 497           497         497  499        파괴된 사나이    2010.7.1
# 498           498         498  500         오직 그대만  2011.10.20
#
#                  매출액       관객수   스크린수            배급사 coach  \
# 0    135,748,398,910  17613682  1,587         씨제이이엔엠   김한민
# 1    139,647,979,516  16264944  1,978         씨제이이엔엠   이병헌
# ...

# %%
df.drop(columns = ['Unnamed: 0.1','Unnamed: 0'], inplace = True)
df
# Out:
#       순위            영화명         개봉일              매출액       관객수   스크린수  \
# 0      1             명량   2014.7.30  135,748,398,910  17613682  1,587
# 1      2           극한직업   2019.1.23  139,647,979,516  16264944  1,978
# 2      3      신과함께-죄와 벌  2017.12.20  115,698,654,137  14410754  1,912
# 3      4           국제시장  2014.12.17  110,913,469,630  14257115    966
# 4      5            베테랑    2015.8.5  105,168,155,250  13414009  1,064
# ..   ...            ...         ...              ...       ...    ...
# 494  496         마음이...  2006.10.26                0   1042166     66
# 495  497  점박이:한반도의 공룡3D   2012.1.26    9,621,468,000   1040636    457
# 496  498            서편제   1993.4.10                0   1035741     16
# 497  499        파괴된 사나이    2010.7.1    7,820,538,614   1030285    190
# 498  500         오직 그대만  2011.10.20    7,591,008,500   1027622    435
#
#                배급사 coach                      actor_main_name  \
# 0           씨제이이엔엠   김한민                ['최민식', '류승룡', '조진웅']
# ...

# %%
dist_unique = list(df['배급사'].unique())

# %%
dist_unique # 62개
# Out:
# ['씨제이이엔엠',
#  '롯데쇼핑㈜롯데엔터테인먼트',
#  '플러스엠 엔터테인먼트',
#  '쇼박스',
#  '넥스트엔터테인먼트월드(NEW)',
#  '주식회사 에이비오엔터테인먼트,플러스엠 엔터테인먼트',
#  '시네마서비스',
#  '롯데컬처웍스롯데엔터테인먼트',
#  '다자인소프트,쇼박스',
#  '씨제이이엔엠,덱스터스튜디오',
#  '워너브러더스 코리아',
#  '이십세기폭스코리아',
#  '플러스엠 엔터테인먼트,키위미디어그룹',
#  '없음',
#  'CGV아트하우스,대명문화공장',
#  '롯데컬처웍스롯데엔터테인먼트,에이스메이커무비웍스',
#  '씨제이이엔엠,시네마서비스',
#  '싸이더스',
#  '롯데쇼핑㈜롯데엔터테인먼트,싸이더스',
#  '와우픽쳐스',
#  '에이스메이커무비웍스,키위미디어그룹',
#  '롯데쇼핑㈜롯데엔터테인먼트,리틀빅픽쳐스',
#  '쇼이스트,씨제이이엔엠',
#  '코리아픽쳐스',
#  '영화사청어람',
#  '프라임엔터테인먼트',
#  '아이러브시네마',
#  '인벤트스톤,영화사청어람',
#  '㈜인디스토리',
#  '씨네월드',
#  '에이스메이커무비웍스',
#  '필라멘트픽쳐스',
#  '엠케이픽처스',
#  '오퍼스픽쳐스(유),CGV아트하우스',
#  '엠케이픽처스 ,두엔터테인먼트',
#  '씨제이이엔엠,아이러브시네마',
#  '쇼이스트',
#  '쇼박스,이십세기폭스코리아',
#  '마인드마크',
#  '에스케이플래닛,씨제이이엔엠',
#  '씨네그루다우기술',
#  '홈초이스,싸이더스',
#  '튜브엔터테인먼트',
#  '시너지하우스 (시너지)',
#  '메리크리스마스,TCO더콘텐츠온',
#  '넥스트엔터테인먼트월드(NEW),에스비에스콘텐츠허브',
#  'CGV아트하우스,영화사 풀',
#  '이언픽쳐스,시네마서비스',
#  '씨너스엔터테인먼트,타임스토리그룹',
#  '에스케이텔레콤',
#  'CGV아트하우스',
#  '㈜스튜디오이쩜영',
#  '팝엔터테인먼트,씨제이이엔엠',
#  '(유)씨에이치엔터테인먼트',
# ...

# %%
len(dist_unique)
# Out:
# 62

# %%
movie_name = list(df['영화명'])

# %%
dist_unique.extend(movie_name)

# %%
len(dist_unique)
# Out:
# 561

# %%
parent = ['']*62

# %%
parent.extend(list(df['배급사']))

# %%
A = df.groupby('배급사')

# %%
B = A['관객수'].sum()

# %%
B
# Out:
# 배급사
# (유)씨에이치엔터테인먼트             1562486
# CGV아트하우스                  6512448
# CGV아트하우스,대명문화공장           4801527
# CGV아트하우스,영화사 풀            1854867
# ㈜스튜디오이쩜영                  2918880
#                            ...
# 플러스엠 엔터테인먼트,주식회사 키위컴퍼니    1387599
# 플러스엠 엔터테인먼트,콘텐츠지오         1094404
# 플러스엠 엔터테인먼트,키위미디어그룹       6879841
# 필라멘트픽쳐스                   2436400
# 홈초이스,싸이더스                 1980769
# Name: 관객수, Length: 62, dtype: int64

# %%
val = [0]*62

# %%
sum(val)
# Out:
# 0

# %%
sum(list(df['관객수']))
# Out:
# 1582690776

# %%
val.extend(list(df['관객수']))

# %%
print(len(dist_unique))
print(len(parent))
print(len(val))
# Out:
# 561
# 561
# 561

# %% [markdown]
# https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query={name}+영화

# %%
urls = {}

for x in range(499):
    name = df['영화명'][x]
    urls[name]= f'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query={name}+영화'
    
urls
# Out:
# {'명량': 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=명량+영화',
#  '극한직업': 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=극한직업+영화',
#  '신과함께-죄와 벌': 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=신과함께-죄와 벌+영화',
#  '국제시장': 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=국제시장+영화',
#  '베테랑': 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=베테랑+영화',
#  '서울의 봄': 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=서울의 봄+영화',
#  '괴물': 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=괴물+영화',
#  '도둑들': 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=도둑들+영화',
#  '7번방의 선물': 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=7번방의 선물+영화',
# ...

# %%
len(urls)
# Out:
# 499

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
# 트리맵 생성
fig = px.treemap(
    names=dist_unique,
    parents=parent,
    values=val
)

fig.update_traces(root_color='#F5F5F5')
fig.update_layout(margin=dict(t=50, l=25, r=25, b=25))

# 각 요소에 정보를 리스트로 제공하여 텍스트로 추가
temp = ['']*62
#texts = [f'<a href="{urls[name]}" target="_blank"><span style="color:red; font-size:10px;">Custom Link</span></a>' for name in gener_unique[18:]]
#texts = [f'<a href="{urls[name]}" target="_blank">Link</a>' for name in gener_unique[18:]]
texts = [f'<a href="{urls[name]}" target="_blank" style="color:black;"><span style="color:white; font-size:10px;">Movie Link</span></a>' for name in dist_unique[62:]]
temp.extend(texts)
fig.update_traces(text=temp)

#fig.update_layout(colorway=px.colors.qualitative.Alphabet)
fig.write_html('de_배급사별영화관객수_링크까지.html')
# 그래프 출력
fig.show()

# %%
texts
# Out:
# ['<a href="https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=명량+영화" target="_blank">Link</a>',
#  '<a href="https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=극한직업+영화" target="_blank">Link</a>',
#  '<a href="https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=신과함께-죄와 벌+영화" target="_blank">Link</a>',
#  '<a href="https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=국제시장+영화" target="_blank">Link</a>',
#  '<a href="https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=베테랑+영화" target="_blank">Link</a>',
#  '<a href="https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=서울의 봄+영화" target="_blank">Link</a>',
#  '<a href="https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=괴물+영화" target="_blank">Link</a>',
# ...
