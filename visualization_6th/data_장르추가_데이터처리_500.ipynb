# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_row', None)

# %%
df1 = pd.read_csv('4.29_500_movies.csv')
df2 = pd.read_csv('4.24_dataset_forviz_final.csv')

# %%
df1
# 여기엔 Unnamed: 0 를 제거해야하고, maker1과 maker2에 있는 정보중에 필요한 것을 살리고, actor부분에서도 필요한 정보들만 새로운 형태로 바꿔서 저장해야한다.
# Out:
#      Unnamed: 0                                              gener coach  \
# 0             0      장편 | 일반영화 | 사극, 액션 | 128분 20초 | 15세이상관람가 | 한국   김한민
# 1             1          장편 | 일반영화 | 코미디 | 111분 0초 | 15세이상관람가 | 한국   이병헌
# 2             2    장편 | 일반영화 | 판타지, 드라마 | 139분 32초 | 12세이상관람가 | 한국   김용화
# 3             3         장편 | 일반영화 | 드라마 | 126분 16초 | 12세이상관람가 | 한국   윤제균
# 4             4     장편 | 일반영화 | 액션, 드라마 | 123분 41초 | 15세이상관람가 | 한국   류승완
# ..          ...                                                ...   ...
# 494         494              장편 | 일반영화 | 드라마 | 97분 0초 | 전체관람가 | 한국   오달균
# 495         495  장편 | 일반영화 | 애니메이션, 어드벤처, 액션 | 88분 0초 | 전체관람가 | 한국   한상호
# 496         496      장편 | 예술영화 | 드라마, 사극 | 112분 0초 | 중학생이상관람가 | 한국   임권택
# 497         497      장편 | 일반영화 | 드라마, 스릴러 | 114분 0초 | 청소년관람불가 | 한국   우민호
# 498         498       장편 | 일반영화 | 멜로/로맨스 | 105분 0초 | 15세이상관람가 | 한국   송일곤
#
#                                                  actor_main  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   499 non-null    int64
#  1   coach        499 non-null    object
#  2   actor_main   499 non-null    object
#  3   actor_sub    484 non-null    object
#  4   actor_cameo  484 non-null    object
#  5   maker1       439 non-null    object
#  6   maker2       383 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 27.4+ KB

# %% [markdown]
# ## 이미 거의다 고친 거므로 un만 삭제해놓자.

# %%
df2
# Out:
#      Unnamed: 0   순위            영화명         개봉일              매출액         관객수  \
# 0             0    1             명량   2014.7.30  135,748,398,910  17,613,682
# 1             1    2           극한직업   2019.1.23  139,647,979,516  16,264,944
# 2             2    3      신과함께-죄와 벌  2017.12.20  115,698,654,137  14,410,754
# 3             3    4           국제시장  2014.12.17  110,913,469,630  14,257,115
# 4             4    5            베테랑    2015.8.5  105,168,155,250  13,414,009
# ..          ...  ...            ...         ...              ...         ...
# 494         495  496         마음이...  2006.10.26                0   1,042,166
# 495         496  497  점박이:한반도의 공룡3D   2012.1.26    9,621,468,000   1,040,636
# 496         497  498            서편제   1993.4.10                0   1,035,741
# 497         498  499        파괴된 사나이    2010.7.1    7,820,538,614   1,030,285
# 498         499  500         오직 그대만  2011.10.20    7,591,008,500   1,027,622
#
# ...

# %%
df2.drop('Unnamed: 0', axis =1, inplace = True)
df2
# Out:
#       순위            영화명         개봉일              매출액         관객수   스크린수  \
# 0      1             명량   2014.7.30  135,748,398,910  17,613,682  1,587
# 1      2           극한직업   2019.1.23  139,647,979,516  16,264,944  1,978
# 2      3      신과함께-죄와 벌  2017.12.20  115,698,654,137  14,410,754  1,912
# 3      4           국제시장  2014.12.17  110,913,469,630  14,257,115    966
# 4      5            베테랑    2015.8.5  105,168,155,250  13,414,009  1,064
# ..   ...            ...         ...              ...         ...    ...
# 494  496         마음이...  2006.10.26                0   1,042,166     66
# 495  497  점박이:한반도의 공룡3D   2012.1.26    9,621,468,000   1,040,636    457
# 496  498            서편제   1993.4.10                0   1,035,741     16
# 497  499        파괴된 사나이    2010.7.1    7,820,538,614   1,030,285    190
# 498  500         오직 그대만  2011.10.20    7,591,008,500   1,027,622    435
#
#                  배급사 coach                      actor_main_name  \
# ...

# %% [markdown]
# 우리는 영화 한개를 뺐으니 그거 하나는 빼야한다.

# %% [markdown]
# ## df1에서 장르만 추출하자

# %%
df1
# Out:
#      Unnamed: 0                                              gener coach  \
# 0             0      장편 | 일반영화 | 사극, 액션 | 128분 20초 | 15세이상관람가 | 한국   김한민
# 1             1          장편 | 일반영화 | 코미디 | 111분 0초 | 15세이상관람가 | 한국   이병헌
# 2             2    장편 | 일반영화 | 판타지, 드라마 | 139분 32초 | 12세이상관람가 | 한국   김용화
# 3             3         장편 | 일반영화 | 드라마 | 126분 16초 | 12세이상관람가 | 한국   윤제균
# 4             4     장편 | 일반영화 | 액션, 드라마 | 123분 41초 | 15세이상관람가 | 한국   류승완
# ..          ...                                                ...   ...
# 494         494              장편 | 일반영화 | 드라마 | 97분 0초 | 전체관람가 | 한국   오달균
# 495         495  장편 | 일반영화 | 애니메이션, 어드벤처, 액션 | 88분 0초 | 전체관람가 | 한국   한상호
# 496         496      장편 | 예술영화 | 드라마, 사극 | 112분 0초 | 중학생이상관람가 | 한국   임권택
# 497         497      장편 | 일반영화 | 드라마, 스릴러 | 114분 0초 | 청소년관람불가 | 한국   우민호
# 498         498       장편 | 일반영화 | 멜로/로맨스 | 105분 0초 | 15세이상관람가 | 한국   송일곤
#
#                                                  actor_main  \
# ...

# %%
df1.drop(columns = 'Unnamed: 0', inplace = True)
df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df1.drop(columns = 'Unnamed: 0', inplace = True)
#       2 df1
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
# ...

# %%
import re

temp_lst = []

for lst in df1['gener']:

    # |을 이용하여 데이터 스플릿
    info = lst.split('|')
    
    temp_lst.append(info[2])



df1['only_gener'] = temp_lst

# # 이름만 들어가진 lst로 채웠다.
df1['only_gener']
# Out:
# 0                사극, 액션
# 1                   코미디
# 2              판타지, 드라마
# 3                   드라마
# 4               액션, 드라마
#              ...
# 494                 드라마
# 495     애니메이션, 어드벤처, 액션
# 496             드라마, 사극
# 497            드라마, 스릴러
# 498              멜로/로맨스
# Name: only_gener, Length: 499, dtype: object

# %%
df1
# Out:
#                                                  gener coach  \
# 0        장편 | 일반영화 | 사극, 액션 | 128분 20초 | 15세이상관람가 | 한국   김한민
# 1            장편 | 일반영화 | 코미디 | 111분 0초 | 15세이상관람가 | 한국   이병헌
# 2      장편 | 일반영화 | 판타지, 드라마 | 139분 32초 | 12세이상관람가 | 한국   김용화
# 3           장편 | 일반영화 | 드라마 | 126분 16초 | 12세이상관람가 | 한국   윤제균
# 4       장편 | 일반영화 | 액션, 드라마 | 123분 41초 | 15세이상관람가 | 한국   류승완
# ..                                                 ...   ...
# 494              장편 | 일반영화 | 드라마 | 97분 0초 | 전체관람가 | 한국   오달균
# 495  장편 | 일반영화 | 애니메이션, 어드벤처, 액션 | 88분 0초 | 전체관람가 | 한국   한상호
# 496      장편 | 예술영화 | 드라마, 사극 | 112분 0초 | 중학생이상관람가 | 한국   임권택
# 497      장편 | 일반영화 | 드라마, 스릴러 | 114분 0초 | 청소년관람불가 | 한국   우민호
# 498       장편 | 일반영화 | 멜로/로맨스 | 105분 0초 | 15세이상관람가 | 한국   송일곤
#
#                                                  actor_main  \
# 0                  [주연] 최민식(이순신 ) | 류승룡(구루지마 ) | 조진웅(와키자카 )
# 1    [주연] 류승룡(고반장) | 이하늬(장형사) | 진선규(마형사) | 이동휘(영호) | 공명(재훈)
# ...

# %% [markdown]
# 여기까지 df1에 있는 모든 내용들을 필요한 부분으로 잘라서 데이터를 만들었으니, df1과 df2을 합치면된다.

# %% [markdown]
# ## df1과 df2 결합

# %%
df = df2.join(df1['only_gener'])

# %%
df
# Out:
#       순위            영화명         개봉일              매출액         관객수   스크린수  \
# 0      1             명량   2014.7.30  135,748,398,910  17,613,682  1,587
# 1      2           극한직업   2019.1.23  139,647,979,516  16,264,944  1,978
# 2      3      신과함께-죄와 벌  2017.12.20  115,698,654,137  14,410,754  1,912
# 3      4           국제시장  2014.12.17  110,913,469,630  14,257,115    966
# 4      5            베테랑    2015.8.5  105,168,155,250  13,414,009  1,064
# ..   ...            ...         ...              ...         ...    ...
# 494  496         마음이...  2006.10.26                0   1,042,166     66
# 495  497  점박이:한반도의 공룡3D   2012.1.26    9,621,468,000   1,040,636    457
# 496  498            서편제   1993.4.10                0   1,035,741     16
# 497  499        파괴된 사나이    2010.7.1    7,820,538,614   1,030,285    190
# 498  500         오직 그대만  2011.10.20    7,591,008,500   1,027,622    435
#
#                  배급사 coach                      actor_main_name  \
# ...

# %%
df.to_csv('5.2_dataset_forviz_add_gener.csv')

# %%
df
# Out:
#       순위            영화명         개봉일              매출액         관객수   스크린수  \
# 0      1             명량   2014.7.30  135,748,398,910  17,613,682  1,587
# 1      2           극한직업   2019.1.23  139,647,979,516  16,264,944  1,978
# 2      3      신과함께-죄와 벌  2017.12.20  115,698,654,137  14,410,754  1,912
# 3      4           국제시장  2014.12.17  110,913,469,630  14,257,115    966
# 4      5            베테랑    2015.8.5  105,168,155,250  13,414,009  1,064
# ..   ...            ...         ...              ...         ...    ...
# 494  496         마음이...  2006.10.26                0   1,042,166     66
# 495  497  점박이:한반도의 공룡3D   2012.1.26    9,621,468,000   1,040,636    457
# 496  498            서편제   1993.4.10                0   1,035,741     16
# 497  499        파괴된 사나이    2010.7.1    7,820,538,614   1,030,285    190
# 498  500         오직 그대만  2011.10.20    7,591,008,500   1,027,622    435
#
#                  배급사 coach                      actor_main_name  \
# ...

# %%
maker_lst = df['maker']

# %%
maker_lst
# Out:
# 0                                                                                                                                    ['(주)빅스톤픽쳐스 BIGSTONEPICTURES']
# 1                                                                                 ['(주)어바웃잇', '영화사 해그림 주식회사 Haegrimm Pictures. Co., Ltd', '(주)씨제이이엔엠 CJ ENM Corp.']
# 2                                                                                     ['리얼라이즈픽쳐스(주) Realies Pictures, Inc.', '(주)덱스터스튜디오 Dexter Studios Co., Ltd.']
# 3                                                                                                                   ['(주)제이케이필름 JK Film', '(주)씨제이이엔엠 CJ ENM Corp.']
# 4                                                                                                                      ['(주)외유내강 Filmmaker R & K', '(주)필름케이 filmK']
# 5                                                                                                                                  ['(주)하이브미디어코프 Hive Media Corp.']
# ...

# %%
for unit in maker_lst:
